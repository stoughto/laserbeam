# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
im = Image.open('half.tif')
#im.show()
imarray = np.array(im)

# %%
imarray.shape
# Out:
# (1024, 1280, 4)

# %%
plt.imshow(imarray[:,:,3], cmap='hot', interpolation='nearest')
